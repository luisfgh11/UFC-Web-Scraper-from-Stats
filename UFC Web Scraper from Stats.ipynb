# %% [markdown]
# This web scraper extracts stats of the fighters from future UFC events stored in the official UFC stats website and export the data to a .csv file, it can be used to create predictive models or other data analysis projects.
#
# - Go to: http://ufcstats.com/statistics/events/upcoming
# - Copy the link of the event you want to extract the data and paste it below:
# - Run all the cells

# %%
URL = "http://ufcstats.com/event-details/ce7871949b0ed2bf"

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def card_event_scraper(URL):
    """
        Receives a card event URL from the Stats UFC page, extracts the info of the card and the links of the matchups
        and return them as two lists.
    """
    # Load HTML file
    req = requests.get(URL)

    # Parse the HTML with BeautifulSoup
    soup = BeautifulSoup(req.text, "html.parser")
    
    # Extract card info
    card_info = []
    card_info.append(soup.find("span", class_="b-content__title-highlight").text.strip())
    date_location = soup.find_all("li", class_="b-list__box-list-item")
    card_info.append(date_location[0].text.strip())
    card_info.append(date_location[1].text.strip())

    # Extract the list of matchups in the card
    matchups = soup.find_all("tr", class_="b-fight-details__table-row b-fight-details__table-row__hover js-fight-details-click")
    # Runs through the list of matchups and extract the third link of each (View matchup)
    links = []
    for matchup in matchups:
        matchup_link = matchup.find_all("a", class_="b-link_style_black")
        links.append(matchup_link[2]['data-link'])
    
    return card_info, links

# %%
def matchup_scraper(URL):
    """
        Receives a matchup URL from the Stats UFC page, extracts the info of red corner and blue corner and return it
        as a concatenated list
    """
    # Load HTML file
    req = requests.get(URL)

    # Parse the HTML with BeautifulSoup
    soup = BeautifulSoup(req.text, "html.parser")

    rc_info = []
    bc_info = []

    # Extract the names (rc = red corner | bc = blue corner)
    names = soup.find_all("a", class_="b-fight-details__table-header-link")
    rc_info.append(names[0].text.strip())
    bc_info.append(names[1].text.strip())

    # Extract stats
    stats = soup.find_all("tr", class_="b-fight-details__table-row-preview") # stats rows
    for stat in stats:
        stats_texts = stat.find_all("td", class_="b-fight-details__table-col")
        rc_info.append(stats_texts[1].text.strip())
        bc_info.append(stats_texts[2].text.strip())

    # Concat rc_info and bc_info
    rc_info.extend(bc_info)
    
    return rc_info

# %%
# GENERATE DATAFRAME

columns = [
    # Columns red corner
    '1_Name', '1_Record', '1_Average_Fight_Time', '1_Height', '1_Weight', '1_Reach',
    '1_Style', '1_day_of_birth', '1_Strikes_Landed_p_min', '1_Striking_Accuracy', 
    '1_Strikes_Absorbed_p_min', '1_Defense_Strike', '1_Takedowns_avg_p_15min', 
    '1_Takedown_Accuracy', '1_Takedown_Defense', '1_Submission_avg_p_15min', 
    '1_Last_fight_1', '1_Last_fight_2', '1_Last_fight_3', '1_Last_fight_4', '1_Last_fight_5',
    # Columns blue corner
    '2_Name', '2_Record', '2_Average_Fight_Time', '2_Height', '2_Weight', '2_Reach',
    '2_Style', '2_day_of_birth', '2_Strikes_Landed_p_min', '2_Striking_Accuracy', 
    '2_Strikes_Absorbed_p_min', '2_Defense_Strike', '2_Takedowns_avg_p_15min', 
    '2_Takedown_Accuracy', '2_Takedown_Defense', '2_Submission_avg_p_15min', 
    '2_Last_fight_1', '2_Last_fight_2', '2_Last_fight_3', '2_Last_fight_4', '2_Last_fight_5',
]

# Extracting data
data = []
links = card_event_scraper(URL)[1]
for link in links:
    data.append(matchup_scraper(link))

# Creating dataframe
df_event = pd.DataFrame(data=data, columns=columns)

# Adding card info at the end
card_info = card_event_scraper(URL)[0]
df_event['card_name'] = card_info[0]
df_event['card_date'] = card_info[1]
df_event['card_location'] = card_info[2]

df_event
# Out:
#               1_Name       1_Record 1_Average_Fight_Time 1_Height  1_Weight  \
# 0    Jared Cannonier         17-8-0                13:46   5' 11"  185 lbs.
# 1      Calvin Kattar         23-8-0                14:45   5' 11"  145 lbs.
# 2   Edmen Shahbazyan         13-5-0                 7:29    6' 2"  185 lbs.
# 3      Ismael Bonfim         20-4-0                10:31    5' 8"  155 lbs.
# 4     Rodolfo Vieira         10-2-0                 8:12    6' 0"  185 lbs.
# 5    Connor Matthews          7-2-0                13:27    5' 8"  145 lbs.
# 6        Angela Hill        17-14-0                14:20    5' 3"  115 lbs.
# 7       Jared Gordon  20-7-0 (1 NC)                11:16    5' 9"  155 lbs.
# 8     Rafael Estevam         12-0-0                11:13    5' 8"  125 lbs.
# 9     Gabriel Bonfim         16-1-0                 6:10    6' 1"  170 lbs.
# 10     Vince Morales         16-8-0                12:20    5' 7"  135 lbs.
# 11    Don'Tale Mayes  11-7-0 (1 NC)                12:30    6' 6"  260 lbs.
# 12       Julia Avila          9-3-0                11:11    5' 7"  135 lbs.
#
#    1_Reach   1_Style 1_day_of_birth 1_Strikes_Landed_p_min  \
# 0      77"    Switch   Mar 16, 1984                   4.49
# 1      72"  Orthodox   Mar 26, 1988                   4.76
# 2      74"  Orthodox   Nov 20, 1997                   3.77
# 3      71"  Orthodox   Dec 28, 1995                   5.80
# 4      73"  Orthodox   Sep 25, 1989                   3.19
# 5      71"    Switch   May 31, 1992                   5.30
# 6      64"  Orthodox   Jan 12, 1985                   5.46
# 7      68"  Orthodox   Sep 06, 1988                   5.75
# 8      69"  Orthodox   Aug 10, 1996                   2.94
# 9      72"  Orthodox   Aug 20, 1997                   5.78
# 10     70"  Orthodox   Nov 12, 1990                   3.98
# 11     81"  Orthodox   Jan 16, 1992                   3.51
# 12     68"  Orthodox   May 11, 1988                   2.59
#
#    1_Striking_Accuracy  ... 2_Takedown_Defense 2_Submission_avg_p_15min  \
# 0                  50%  ...               100%                      0.4
# 1                  39%  ...                59%                      1.5
# 2                  50%  ...                76%                      0.4
# 3                  54%  ...                75%                      0.3
# 4                  54%  ...                80%                      1.7
# 5                  44%  ...               100%                      0.0
# 6                  49%  ...                62%                      0.8
# 7                  55%  ...                 0%                      0.0
# 8                  64%  ...                36%                      1.8
# 9                  42%  ...                80%                      0.0
# 10                 36%  ...               100%                      1.0
# 11                 43%  ...                 0%                      0.8
# 12                 43%  ...                90%                      0.0
#
#       2_Last_fight_1  2_Last_fight_2     2_Last_fight_3     2_Last_fight_4  \
# 0       Win - Duncan   Win - Tavares    Win - Tiuliulin    Loss - Ferreira
# 1        Win - Shore    Win - Errens  Win - Quarantillo  Draw - Blackshear
# 2    Loss - Petroski  Loss - Almeida      Win - Hanekom
# 3   Draw - Borshchev  Win - McKinney        Win - Elder   Win - Hassanzada
# 4        Win - Budka     Win - Fremd     Loss - Malkoun     Loss - Pereira
# 5       Win - Juarez
# 6     Win - Jauregui      Win - Mann       Loss - Silva
# 7
# 8       Win - Nicoll  Win - Mendonca         Win - Ross       Loss - Taira
# 9       Win - Harris    Win - Bedoya       Loss - Brown        Win - Baeza
# 10         Win - Tau
# 11        Win - Tafa  Loss - Brzeski
# 12    Win - Cornolle     Win - Nunes        Win - Fairn
#
#         2_Last_fight_5                                 card_name  \
# 0       Win - Njokuani  UFC Fight Night: Cannonier vs. Rodrigues
# 1       Loss - Woodson  UFC Fight Night: Cannonier vs. Rodrigues
# 2                       UFC Fight Night: Cannonier vs. Rodrigues
# 3                       UFC Fight Night: Cannonier vs. Rodrigues
# 4    Win - Meerschaert  UFC Fight Night: Cannonier vs. Rodrigues
# 5                       UFC Fight Night: Cannonier vs. Rodrigues
# 6                       UFC Fight Night: Cannonier vs. Rodrigues
# 7                       UFC Fight Night: Cannonier vs. Rodrigues
# 8       Win - Ferreira  UFC Fight Night: Cannonier vs. Rodrigues
# 9   Win - Semelsberger  UFC Fight Night: Cannonier vs. Rodrigues
# 10                      UFC Fight Night: Cannonier vs. Rodrigues
# 11                      UFC Fight Night: Cannonier vs. Rodrigues
# 12                      UFC Fight Night: Cannonier vs. Rodrigues
#
#                                  card_date  \
# 0   Date:\n      \n      February 15, 2025
# 1   Date:\n      \n      February 15, 2025
# 2   Date:\n      \n      February 15, 2025
# 3   Date:\n      \n      February 15, 2025
# 4   Date:\n      \n      February 15, 2025
# 5   Date:\n      \n      February 15, 2025
# 6   Date:\n      \n      February 15, 2025
# 7   Date:\n      \n      February 15, 2025
# 8   Date:\n      \n      February 15, 2025
# 9   Date:\n      \n      February 15, 2025
# 10  Date:\n      \n      February 15, 2025
# 11  Date:\n      \n      February 15, 2025
# 12  Date:\n      \n      February 15, 2025
#
#                                         card_location
# 0   Location:\n      \n\n      Las Vegas, Nevada, USA
# 1   Location:\n      \n\n      Las Vegas, Nevada, USA
# 2   Location:\n      \n\n      Las Vegas, Nevada, USA
# 3   Location:\n      \n\n      Las Vegas, Nevada, USA
# 4   Location:\n      \n\n      Las Vegas, Nevada, USA
# 5   Location:\n      \n\n      Las Vegas, Nevada, USA
# 6   Location:\n      \n\n      Las Vegas, Nevada, USA
# 7   Location:\n      \n\n      Las Vegas, Nevada, USA
# 8   Location:\n      \n\n      Las Vegas, Nevada, USA
# 9   Location:\n      \n\n      Las Vegas, Nevada, USA
# 10  Location:\n      \n\n      Las Vegas, Nevada, USA
# 11  Location:\n      \n\n      Las Vegas, Nevada, USA
# 12  Location:\n      \n\n      Las Vegas, Nevada, USA
#
# [13 rows x 45 columns]

# %%
# Create title file removing special characters
import re
title_file = re.sub(r'[\\/*?:"<>|.]', "", card_info[0]) + ".csv"
#Export the data
df_event.to_csv(title_file, index = False)
print("Data exported succesfully!")
# Out:
# Data exported succesfully!
